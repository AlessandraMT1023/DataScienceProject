# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# En este cuaderno, se resumen las herramientas y ecosistemas de ciencia de datos.

# %% [markdown]
# **Objetivos**
#
# - Listar los lenguajes populares para Ciencia de Datos.
# - Conocer las bibliotecas más usadas en Ciencia de Datos.
# - Identificar herramientas de desarrollo y entornos para Ciencia de Datos.
# - Aprender a realizar operaciones aritméticas básicas en Python.
# - Crear y compartir un cuaderno Jupyter para documentar el trabajo.

# %% [markdown]
# Algunos de los lenguajes populares que utilizan los científicos de datos son:
#
# 1. SQL
# 2. Python
# 3. R
# 4. Java

# %% [markdown]
# Algunas de las bibliotecas comúnmente utilizadas por los científicos de datos incluyen:
#
# 1. Pandas
# 2. NumPy
# 3. Matplotlib
# 4. TensorFlow

# %% [markdown]
# | Herramientas de ciencia de datos |
# |----------------------------------|
# | Jupyter Notebook                 |
# | RStudio                          |
# | Apache Spark                     |

# %% [markdown]
# ### A continuación, se presentan algunos ejemplos de evaluación de expresiones aritméticas en Python

# %%
# Esta es una expresión aritmética simple para multiplicar y luego sumar enteros
(3*4)+5
# Out:
# 17

# %%
# Esto convertirá 200 minutos a horas dividiendo por 60
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Autor
# Alessandra Mejía Tirado
